# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
# preset file path 1
whale_csv=Path(r"C:\Users\MK\Desktop\UTOR-VIRT-FIN-PT-08-2023-U-LOLC\04-Pandas\Unit 4 Homework\Instructions\Starter_Code\Resources\whale_returns.csv")

# %%
# Reading whale returns
whale_data= pd.read_csv(whale_csv,index_col="Date", infer_datetime_format=True, parse_dates=True) #Read the CSV into a DataFrame 
whale_data.head() # Display a few rows
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_data.count()
# Out:
# SOROS FUND MANAGEMENT LLC      1059
# PAULSON & CO.INC.              1059
# TIGER GLOBAL MANAGEMENT LLC    1059
# BERKSHIRE HATHAWAY INC         1059
# dtype: int64

# %%
# Drop nulls
whale_data.dropna(inplace=True) # Drops all columns that are true 
whale_data #Display the data
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
#Verifying all nulls have been eliminated
whale_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_path=Path(r"C:\Users\MK\Desktop\UTOR-VIRT-FIN-PT-08-2023-U-LOLC\04-Pandas\Unit 4 Homework\Instructions\Starter_Code\Resources\algo_returns.csv")
# Reading algorithmic returns
algo_data= pd.read_csv(algo_path,index_col="Date", infer_datetime_format=True, parse_dates=True) # Reads the CSV into a Data Frame
algo_data.head() #Displays a few rows
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_data.count()
# Out:
# Algo 1    1241
# Algo 2    1235
# dtype: int64

# %%
# Drop nulls
algo_data.dropna(inplace=True) # Drops all columns that are true 
algo_data # Displays the Data
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
SP60_path=Path(r"C:\Users\MK\Desktop\UTOR-VIRT-FIN-PT-08-2023-U-LOLC\04-Pandas\Unit 4 Homework\Instructions\Starter_Code\Resources\sp_tsx_history.csv")
# Reading S&P TSX 60 Closing Prices
SP60_data= pd.read_csv(SP60_path,index_col="Date", infer_datetime_format=True, parse_dates=True) # Reads the CSV into a DataFrame
SP60_data.head() #Displays a few rows
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
SP60_data.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
SP60_data["Close"] = SP60_data["Close"].str.replace("$", "")
SP60_data["Close"] = SP60_data["Close"].str.replace(",", "").astype(float)
# Out:
# C:\Users\MK\AppData\Local\Temp\ipykernel_7016\1378962524.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   SP60_data["Close"] = SP60_data["Close"].str.replace("$", "")

# %%
# Calculate Daily Returns
SP60_return=SP60_data.pct_change() #Calculates
SP60_return.head() #Displays
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305

# %%
# Drop nulls
SP60_return.dropna()
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1817 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
columns=['Daily Return SP60'] # Naming new column
SP60_return.columns=columns # renaming
SP60_return.head() # Display rows
# Out:
#             Daily Return SP60
# Date
# 2012-10-01                NaN
# 2012-10-02           0.001701
# 2012-10-03          -0.002563
# 2012-10-04           0.007137
# 2012-10-05          -0.002305

# %%
SP60_return.dropna(inplace=True) # Drop all nulls
SP60_return.head() # Display rows
# Out:
#             Daily Return SP60
# Date
# 2012-10-02           0.001701
# 2012-10-03          -0.002563
# 2012-10-04           0.007137
# 2012-10-05          -0.002305
# 2012-10-09          -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
Trio_df=pd.concat([whale_data,algo_data,SP60_return],axis="columns",join="inner") # Concat all three portfolios
Trio_df.head() #Displays a few rows
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  Daily Return SP60
# Date
# 2015-03-03 -0.000949          -0.008530
# 2015-03-04  0.002416          -0.003371
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
whale_data.plot(figsize=(10,5)) # Plots the Daily returns Whale Data 
algo_data.plot(figsize=(10,5)) # Plots the Daily returns of Algo Data 
SP60_return.plot(figsize=(10,5)) # Plots the Daily returns SP60
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
#Cumulative returns of Whale Data
cumulative_returns1 = (1 + whale_data).cumprod() - 1 # Calculate Cumulative Return using cumprod function for Whale Data
cumulative_returns1 # Displays a few rows
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000962           -0.001755
# 2015-03-05                   0.004981            0.002314
# 2015-03-06                  -0.002963           -0.001269
# 2015-03-09                  -0.002383            0.002951
# ...                               ...                 ...
# 2019-04-25                   0.166895           -0.220575
# 2019-04-26                   0.176404           -0.213434
# 2019-04-29                   0.177880           -0.211295
# 2019-04-30                   0.176355           -0.213039
# 2019-05-01                   0.169477           -0.214095
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.003028               -0.002383
# ...

# %%
#Cumulative Return for Algo Data
cumulative_returns2 = (1 + algo_data).cumprod() - 1 ## Calculate Cumulative Return using cumprod function for Algo Data
cumulative_returns2 #Display a few Rows
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.005927  0.021679
# 2014-06-09  0.000885  0.027470
# 2014-06-10  0.005295  0.026714
# 2014-06-11  0.010081  0.022852
# ...              ...       ...
# 2019-04-25  1.145762  0.458997
# 2019-04-26  1.152159  0.466665
# 2019-04-29  1.163367  0.470814
# 2019-04-30  1.156999  0.468506
# 2019-05-01  1.157201  0.457700
#
# [1235 rows x 2 columns]

# %%
#Cumulative Return for SP60 Data
cumulative_returns3 = (1 + SP60_return).cumprod() - 1 ## Calculate Cumulative Return using cumprod function for SP60 Data
cumulative_returns3 #Display a few Rows
# Out:
#             Daily Return SP60
# Date
# 2012-10-02           0.001701
# 2012-10-03          -0.000867
# 2012-10-04           0.006264
# 2012-10-05           0.003945
# 2012-10-09          -0.007811
# ...                       ...
# 2019-12-20           0.383846
# 2019-12-23           0.384676
# 2019-12-24           0.388835
# 2019-12-27           0.387870
# 2019-12-30           0.382239
#
# [1817 rows x 1 columns]

# %%
# Plot cumulative returns
cumulative_returns1.plot(figsize=(10,5),title=" Cumulative Returns of Whale Data ") #Plots Cumulative Return for Whale Data
cumulative_returns2.plot(figsize=(10,5),title=" Cumulative Returns of Algo Data ") #Plots Cumulative Return for Algo Data
cumulative_returns3.plot(figsize=(10,5),title=" Cumulative Returns of SP60 Data ") #Plots Cumulative Retur
# Out:
# <Axes: title={'center': ' Cumulative Returns of SP60 Data '}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
plt.boxplot(whale_data); # Box plot of Whale Data

# %%
plt.boxplot(algo_data);  # Box plot of Algo Data

# %%
plt.boxplot(SP60_data);  # Box plot of SP60 Data

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# standard Deviations of Whale Data
whale_std=whale_data.std()
whale_std # Displays Results
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64

# %%
# Daily Standard Deviations of Algo Data
algo_std=algo_data.std() 
algo_std
# Out:
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64

# %%
# Daily Standard Deviations of SP60 Data
SP60_std=SP60_return.std() 
SP60_std
# Out:
# Daily Return SP60    0.006637
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60

# Determine which portfolios are riskier than the S&P TSX 60
#riskier than the S&P TSX 60 are : Soros Fund Mangement, Paulson & Co ,Tiger global

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
# Annual Standard Deviation of Whale Data
trading_days=252 # Variable to contain the trading days
annual_std=whale_std*np.sqrt(trading_days) # We multiply the daily std of said data then square root it by the number of trading days
annual_std # Display Results
# Out:
# SOROS FUND MANAGEMENT LLC      0.124487
# PAULSON & CO.INC.              0.110754
# TIGER GLOBAL MANAGEMENT LLC    0.171830
# BERKSHIRE HATHAWAY INC         0.203682
# dtype: float64

# %%
# Annual Standard Deviation of Algo Data

trading_days=252 
annual_std2=algo_std*np.sqrt(trading_days) 
annual_std2
# Out:
# Algo 1    0.126801
# Algo 2    0.134401
# dtype: float64

# %%
# Annual Standard Deviation of SP60 Data

trading_days=252 
annual_std3=SP60_std*np.sqrt(trading_days)
annual_std3
# Out:
# Daily Return SP60    0.105365
# dtype: float64

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window


rolling_std1 = whale_data.rolling(window=21).std() # Calculate Rolling Standard Deviation using a 21 day window
rolling_std1.plot(figsize=(10,5),title=" Whale Data Rolling Standard Deviation (21 day window)"); # Plot the rolling standard deviation with title name

rolling_std2 = algo_data.rolling(window=21).std() # Calculate Rolling Standard Deviation using a 21 day window
rolling_std2.plot(figsize=(10,5),title=" Algo Data Rolling Standard Deviation (21 day window)"); # Plot the rolling standard deviation with title name

rolling_std3 = SP60_return.rolling(window=21).std() # Calculate Rolling Standard Deviation using a 21 day window
rolling_std3.plot(figsize=(10,5),title=" SP60 Rolling Standard Deviation (21 day window)"); # Plot t

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation1= whale_data.corr()
# Display de correlation matrix
sns.heatmap(correlation1)
# Out:
# <Axes: >

# %%
# Calculate the correlation
correlation2= algo_data.corr()
# Display de correlation matrix
sns.heatmap(correlation2)
# Out:
# <Axes: >

# %%
# Calculate the correlation
correlation3= SP60_return.corr()
# Display de correlation matrix
sns.heatmap(correlation3)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
covariance = algo_data['Algo 1'].cov(SP60_return['Daily Return SP60']) # Calculating Covariance from Algo Data and SP60 Data
covariance # Displays Covariance
# Calculate variance of S&P TSX
variance = SP60_return['Daily Return SP60'].var() # Calculating Variance from SP60 Data
variance # Displays Variance
# Computing beta
algo_beta= covariance/variance #/ COVARIANCE
algo_beta # Displays Results
# Plot beta trend
plt.bar('Beta Trend', 0.015326825843501595)
# Out:
# <BarContainer object of 1 artists>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window: Whale Data
halflife=21 # Specifying halflife period
ewm_result1 = whale_data.ewm(halflife=halflife).std() # Calculates the Exponentially Weighted Average using std as the metric 
ewm_result1 # Displays Result
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
# ...                               ...                 ...
# 2019-04-25                   0.007066            0.006472
# 2019-04-26                   0.007054            0.006569
# 2019-04-29                   0.006939            0.006475
# 2019-04-30                   0.006845            0.006387
# 2019-05-01                   0.006860            0.006290
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                          NaN                     NaN
# 2015-03-04                     0.001441                0.007624
# ...

# %%
halflife=21 # Specifying halflife period
ewm_result2 = algo_data.ewm(halflife=halflife).std() # Calculates the Exponentially Weighted Average using std as the metric 
ewm_result2 # Displays Result
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05       NaN       NaN
# 2014-06-06  0.001560  0.003536
# 2014-06-09  0.004757  0.003857
# 2014-06-10  0.004404  0.005849
# 2014-06-11  0.004100  0.006861
# ...              ...       ...
# 2019-04-25  0.006583  0.007605
# 2019-04-26  0.006489  0.007520
# 2019-04-29  0.006432  0.007404
# 2019-04-30  0.006364  0.007299
# 2019-05-01  0.006261  0.007335
#
# [1235 rows x 2 columns]

# %%
halflife=21 # Specifying halflife period
ewm_result3 = SP60_return.ewm(halflife=halflife).std() # Calculates the Exponentially Weighted Average using std as the metric 
ewm_result3 # Displays Result
# Out:
#             Daily Return SP60
# Date
# 2012-10-02                NaN
# 2012-10-03           0.003015
# 2012-10-04           0.004905
# 2012-10-05           0.004572
# 2012-10-09           0.007017
# ...                       ...
# 2019-12-20           0.003575
# 2019-12-23           0.003517
# 2019-12-24           0.003486
# 2019-12-27           0.003438
# 2019-12-30           0.003484
#
# [1817 rows x 1 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = ((Trio_df.mean()) * 252) / (Trio_df.std() * np.sqrt(252)) # Calculate the mean of each portfolio then divide it by the standard deviation. We then multiply by the square root of the trading days (252)
sharpe_ratios #Display Data
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# Daily Return SP60              0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios") # Visualizes a bar plot
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
# # The Sharpe ratio for Algo 1 is 1.070733, followed by Algo 2 (0.804573) and Daily Return SP60 (0.502295). These algorithmic strategies have positive Sharpe ratios, indicating that they outperformed the risk-free rate in terms of risk-adjusted returns.
# # Soros Fund Management LLC and Berkshire Hathaway Inc both have positive Sharpe ratios, indicating that they have performed well when risk is taken into account.
# # Paulson & Co. Inc. and Tiger Global Management LLC both have negative Sharpe ratios, indicating that their returns have not compensated for the risk they have taken.
# # In terms of risk-adjusted returns, both Algo 1 and Algo 2 outperform the market (S&P TSX 60) and the whale portfolios.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
L_loco=Path(r"C:\Users\MK\Desktop\UTOR-VIRT-FIN-PT-08-2023-U-LOLC\04-Pandas\Unit 4 Homework\Instructions\Starter_Code\Resources\l_historical.csv") #Location Path of my L_historical CSV
L_data=pd.read_csv(L_loco, index_col="Date", infer_datetime_format=True, parse_dates=True) # Reads CSV into Data Frame
L_data # Displays Data Frame
# Out:
#            Symbol  Close
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86
# ...           ...    ...
# 2019-12-20      L  67.90
# 2019-12-23      L  67.68
# 2019-12-24      L  67.67
# 2019-12-27      L  67.78
# 2019-12-30      L  67.33
#
# [501 rows x 2 columns]

# %%
# Reading data from 2nd stock
otex_loco=Path(r"C:\Users\MK\Desktop\UTOR-VIRT-FIN-PT-08-2023-U-LOLC\04-Pandas\Unit 4 Homework\Instructions\Starter_Code\Resources\otex_historical.csv") #Location Path of my Otex_historical CSV
otex_data=pd.read_csv(otex_loco,index_col="Date", infer_datetime_format=True, parse_dates=True) # Reads CSV into Data Frame
otex_data # Displays Data Frame
# Out:
#            Symbol  Close
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16
# ...           ...    ...
# 2019-12-20   OTEX  58.68
# 2019-12-23   OTEX  57.89
# 2019-12-24   OTEX  57.44
# 2019-12-27   OTEX  57.70
# 2019-12-30   OTEX  57.19
#
# [501 rows x 2 columns]

# %%
# Reading data from 3rd stock
# Reading data from 3rd stock
shop_loco=Path(r"C:\Users\MK\Desktop\UTOR-VIRT-FIN-PT-08-2023-U-LOLC\04-Pandas\Unit 4 Homework\Instructions\Starter_Code\Resources\shop_historical.csv") #Location Path of my Shop_historical CSV
shop_data=pd.read_csv(shop_loco,index_col="Date", infer_datetime_format=True, parse_dates=True)# Reads CSV into Data Frame
shop_data # Displays Data Frame
# Out:
#            Symbol   Close
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51
# ...           ...     ...
# 2019-12-20   SHOP  513.22
# 2019-12-23   SHOP  511.62
# 2019-12-24   SHOP  525.39
# 2019-12-27   SHOP  534.76
# 2019-12-30   SHOP  517.79
#
# [501 rows x 2 columns]

# %%
# Combine all stocks in a single DataFrame
trio1_data=pd.concat([L_data,otex_data,shop_data],axis="rows",join="inner") # Concats three data frames in one 
trio1_data # Displays the result
# Out:
#            Symbol   Close
# Date
# 2018-01-02      L   57.99
# 2018-01-03      L   57.41
# 2018-01-04      L   57.42
# 2018-01-05      L   57.42
# 2018-01-08      L   56.86
# ...           ...     ...
# 2019-12-20   SHOP  513.22
# 2019-12-23   SHOP  511.62
# 2019-12-24   SHOP  525.39
# 2019-12-27   SHOP  534.76
# 2019-12-30   SHOP  517.79
#
# [1503 rows x 2 columns]

# %%
# Reset Date index
trio1_reset = trio1_data.reset_index()
trio1_reset
# Out:
#            Date Symbol   Close
# 0    2018-01-02      L   57.99
# 1    2018-01-03      L   57.41
# 2    2018-01-04      L   57.42
# 3    2018-01-05      L   57.42
# 4    2018-01-08      L   56.86
# ...         ...    ...     ...
# 1498 2019-12-20   SHOP  513.22
# 1499 2019-12-23   SHOP  511.62
# 1500 2019-12-24   SHOP  525.39
# 1501 2019-12-27   SHOP  534.76
# 1502 2019-12-30   SHOP  517.79
#
# [1503 rows x 3 columns]

# %%
# Reorganize portfolio data by having a column per symbol
trio_port= trio1_data.pivot_table(values="Close", index="Date", columns="Symbol") # Reorganize the Data
trio_port # Display Data
# Out:
# Symbol          L   OTEX    SHOP
# Date
# 2018-01-02  57.99  43.58  132.06
# 2018-01-03  57.41  43.07  135.15
# 2018-01-04  57.42  42.91  137.46
# 2018-01-05  57.42  42.57  137.26
# 2018-01-08  56.86  42.16  139.51
# ...           ...    ...     ...
# 2019-12-20  67.90  58.68  513.22
# 2019-12-23  67.68  57.89  511.62
# 2019-12-24  67.67  57.44  525.39
# 2019-12-27  67.78  57.70  534.76
# 2019-12-30  67.33  57.19  517.79
#
# [501 rows x 3 columns]

# %%
# Calculate daily returns
trio1_return=trio_port.pct_change()
trio1_return
# Drop NAs
trio1_return.dropna(inplace=True)
# Display sample data
trio1_return
# Out:
# Symbol             L      OTEX      SHOP
# Date
# 2018-01-03 -0.010002 -0.011703  0.023398
# 2018-01-04  0.000174 -0.003715  0.017092
# 2018-01-05  0.000000 -0.007924 -0.001455
# 2018-01-08 -0.009753 -0.009631  0.016392
# 2018-01-09  0.008969 -0.000712 -0.011254
# ...              ...       ...       ...
# 2019-12-20  0.003547  0.024441 -0.005503
# 2019-12-23 -0.003240 -0.013463 -0.003118
# 2019-12-24 -0.000148 -0.007773  0.026915
# 2019-12-27  0.001626  0.004526  0.017834
# 2019-12-30 -0.006639 -0.008839 -0.031734
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]
# Calculate portfolio return
port_return = trio1_return.dot(weights)
# Display sample data
port_return.head(10)
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
# 2018-01-10    0.000528
# 2018-01-11    0.000213
# 2018-01-12    0.004051
# 2018-01-15    0.004226
# 2018-01-16   -0.008559
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
Trio_df["custom"]=port_return # Creates a Custom Dataframe to include the weigheted Returns
Trio_df.tail() # Displays Results
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-25                    -0.005153                0.004848  0.000682
# 2019-04-26                     0.012355                0.010434  0.002981
# 2019-04-29                     0.006251                0.005223  0.005208
# 2019-04-30                    -0.000259               -0.003702 -0.002944
# 2019-05-01                    -0.007936               -0.007833  0.000094
#
#               Algo 2  Daily Return SP60    custom
# Date
# 2019-04-25 -0.007247          -0.000628  0.003461
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
Trio_df.dropna(inplace=True) # Eliminate all NaNs
Trio_df.head() # Display Results
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# 2018-01-05                     0.000737                0.022023 -0.003839
# 2018-01-08                     0.005085                0.003435  0.001653
# 2018-01-09                     0.001789                0.000708 -0.001004
#
#               Algo 2  Daily Return SP60    custom
# Date
# 2018-01-03  0.008175           0.003774  0.000565
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
trading_days=252 # Variable to contain the trading days
annual_std1=Trio_df*np.sqrt(trading_days) # We multiply the daily std of said data then square root it by the number of trading days
annual_std1
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03                   0.073936            0.000430
# 2018-01-04                  -0.014515            0.066617
# 2018-01-05                   0.064634            0.013069
# 2018-01-08                   0.071000           -0.059350
# 2018-01-09                  -0.016311            0.013847
# ...                               ...                 ...
# 2019-04-25                  -0.004522           -0.020491
# 2019-04-26                   0.129369            0.145437
# 2019-04-29                   0.019912            0.043165
# 2019-04-30                  -0.020550           -0.035106
# 2019-05-01                  -0.092819           -0.021291
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-01-03                     0.031413                0.090108 -0.014132
# 2018-01-04                     0.170537                0.064527 -0.014511
# ...

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_std4 = Trio_df.rolling(window=21).std() # Calculate Rolling Standard Deviation using a 21 day window
# Plot rolling standard deviation
rolling_std4.plot(figsize=(10,5),title=" Trio Data Rolling Standard Deviation (21 day window)");

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation4 = Trio_df.corr() # Calculate Correlation
sns.heatmap(correlation4); # Plots Correlation

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta

rolling_covariance = Trio_df["custom"].rolling(window=60).cov(SP60_return["Daily Return SP60"]) # Calculates Rolling Varriance between Custom and SP 60
rolling_variance = SP60_return["Daily Return SP60"].rolling(window=60).var() # Calculates Variance
rolling_beta = rolling_covariance / rolling_variance # Calculates Beta

rolling_beta.head() # Displays the results
# Out:
# Date
# 2012-10-02   NaN
# 2012-10-03   NaN
# 2012-10-04   NaN
# 2012-10-05   NaN
# 2012-10-09   NaN
# dtype: float64

# %%
plt.bar('Beta Trend', rolling_beta);

# %% [markdown]
# plt.bar('Beta Trend', rolling_beta);### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios1 = ((trio1_return.mean()) * 252) / (trio1_return.std() * np.sqrt(252)) # Calculate the mean of each portfolio then divide it by the standard deviation. We then multiply by the square root of the trading days (252)
sharpe_ratios1 #Display Data
# Out:
# Symbol
# L       0.570084
# OTEX    0.743512
# SHOP    1.655513
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios1.plot(kind="bar", title="Sharpe Ratios"); # Visualizes a bar plot

# %% [markdown]
# ### How does your portfolio do?
#
# #L (Assumed Weight: 1/3): yielded a return of about 0.5701. It contributed positively to the performance of my portfolio, but it is the worst performer of the three assets.
#
# #OTEX (Assumed Weight: 1/3): OTEX returned approximately 0.7435. It had a positive impact on the performance of my portfolio, outperforming asset L.
#
# #SHOP (Supposed Weight: 1/3): SHOP had the highest return of the three assets, with a return of approximately 1.6555. It significantly increased the overall return of the portfolio.
#
# #Overall, it appears that my portfolio performed well, with positive returns from all three assets.
